# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Read Diagnosis dataset

# %%
df = pd.read_csv("diagnosed_cbc_data_v4.csv", sep=",")
df.head(n=5)
# Out:
#     WBC  LYMp  NEUTp  LYMn  NEUTn   RBC  HGB    HCT   MCV   MCH  MCHC    PLT  \
# 0  10.0  43.2   50.1   4.3    5.0  2.77  7.3   24.2  87.7  26.3  30.1  189.0
# 1  10.0  42.4   52.3   4.2    5.3  2.84  7.3   25.0  88.2  25.7  20.2  180.0
# 2   7.2  30.7   60.7   2.2    4.4  3.97  9.0   30.5  77.0  22.6  29.5  148.0
# 3   6.0  30.2   63.5   1.8    3.8  4.22  3.8   32.8  77.9  23.2  29.8  143.0
# 4   4.2  39.1   53.7   1.6    2.3  3.93  0.4  316.0  80.6  23.9  29.7  236.0
#
#     PDW   PCT                      Diagnosis
# 0  12.5  0.17  Normocytic hypochromic anemia
# 1  12.5  0.16  Normocytic hypochromic anemia
# 2  14.3  0.14         Iron deficiency anemia
# 3  11.3  0.12         Iron deficiency anemia
# 4  12.8  0.22  Normocytic hypochromic anemia

# %% [markdown]
# Check all Datatypes

# %%
df.dtypes
# Out:
# WBC          float64
# LYMp         float64
# NEUTp        float64
# LYMn         float64
# NEUTn        float64
# RBC          float64
# HGB          float64
# HCT          float64
# MCV          float64
# MCH          float64
# MCHC         float64
# PLT          float64
# PDW          float64
# PCT          float64
# Diagnosis     object
# dtype: object

# %% [markdown]
# Check for duplicates

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# Display all duplicate rows

# %%
df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head(100)
# Out:
#         WBC    LYMp   NEUTp     LYMn     NEUTn   RBC   HGB      HCT    MCV  \
# 935    2.88  25.845  77.511  1.88076   5.14094  3.01   9.0  46.1526  103.7
# 951    2.88  25.845  77.511  1.88076   5.14094  3.01   9.0  46.1526  103.7
# 452    3.10  20.300  72.100  0.60000   2.30000  5.36  12.2  40.4000   75.5
# 467    3.10  20.300  72.100  0.60000   2.30000  5.36  12.2  40.4000   75.5
# 90     3.20  35.600  56.200  1.10000   1.80000  5.22  14.9  45.8000   87.8
# ...     ...     ...     ...      ...       ...   ...   ...      ...    ...
# 982   15.53  25.845  77.511  1.88076   5.14094  3.52   9.7  46.1526   88.1
# 430   21.20  13.900  80.300  3.00000  17.00000  5.70  14.4  48.4000   85.1
# 474   21.20  13.900  80.300  3.00000  17.00000  5.70  14.4  48.4000   85.1
# 1155  22.90  25.845  77.511  1.88076   5.14094  5.55  14.3  46.1526   89.2
# 1162  22.90  25.845  77.511  1.88076   5.14094  5.55  14.3  46.1526   89.2
#
# ...

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#     WBC  LYMp  NEUTp  LYMn  NEUTn   RBC  HGB    HCT   MCV   MCH  MCHC    PLT  \
# 0  10.0  43.2   50.1   4.3    5.0  2.77  7.3   24.2  87.7  26.3  30.1  189.0
# 1  10.0  42.4   52.3   4.2    5.3  2.84  7.3   25.0  88.2  25.7  20.2  180.0
# 2   7.2  30.7   60.7   2.2    4.4  3.97  9.0   30.5  77.0  22.6  29.5  148.0
# 3   6.0  30.2   63.5   1.8    3.8  4.22  3.8   32.8  77.9  23.2  29.8  143.0
# 4   4.2  39.1   53.7   1.6    2.3  3.93  0.4  316.0  80.6  23.9  29.7  236.0
#
#     PDW   PCT                      Diagnosis
# 0  12.5  0.17  Normocytic hypochromic anemia
# 1  12.5  0.16  Normocytic hypochromic anemia
# 2  14.3  0.14         Iron deficiency anemia
# 3  11.3  0.12         Iron deficiency anemia
# 4  12.8  0.22  Normocytic hypochromic anemia

# %% [markdown]
# Get total rows after dropping all duplicates

# %%
df.count
# Out:
# <bound method DataFrame.count of         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1276   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1277   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1278   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1279   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1280   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
# ...

# %% [markdown]
# Check if there's empty cells

# %%
df.isna().any() # add another .any() to aggregate to a single Boolean
# Out:
# WBC          False
# LYMp         False
# NEUTp        False
# LYMn         False
# NEUTn        False
# RBC          False
# HGB          False
# HCT          False
# MCV          False
# MCH          False
# MCHC         False
# PLT          False
# PDW          False
# PCT          False
# Diagnosis    False
# dtype: bool

# %% [markdown]
# Get statistical overview of data

# %%
df.describe()
# Out:
#                WBC         LYMp        NEUTp         LYMn        NEUTn  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      7.846713    25.897658    77.591978     1.884341     5.130724
# std       3.552180     7.064941   150.651596     1.357362     2.895636
# min       0.800000     6.200000     0.700000     0.200000     0.500000
# 25%       6.000000    25.845000    70.775000     1.880760     5.000000
# 50%       7.400000    25.845000    77.511000     1.880760     5.140940
# 75%       8.700000    25.845000    77.511000     1.880760     5.140940
# max      45.700000    91.400000  5317.000000    41.800000    79.000000
#
#                RBC          HGB          HCT          MCV          MCH  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean      4.714294    12.187589    46.269150    85.734099    32.250877
# std       2.867519     3.863201   106.945982    27.663902   113.356653
# ...

# %% [markdown]
# Correlation matrix

# %%
plt.subplots(figsize=(12, 12))
df_iron = df[df["Diagnosis"] == "Macrocytic anemia"]

X = df_iron.drop('Diagnosis', axis=1)
sns.heatmap(X.corr(), annot=True, cmap='RdYlGn_r', linewidths=0.5, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Detail Boxplot per Disease

# %%
df_iron = df[df["Diagnosis"] == "Iron deficiency anemia"]

feature_cols = df_iron.select_dtypes(include="number").columns

plt.figure(figsize=(12, 6))
df_iron[feature_cols].plot(kind='box', subplots=True, layout=(7, 2), figsize=(10, 18), sharex=False)
plt.title("Boxplots der numerischen Features – Iron Deficiency Anemia")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Boxplot of feature values per Disease side by side

# %%
df_iron = df[df["Diagnosis"] == "Iron deficiency anemia"]

feature_cols = df_iron.select_dtypes(include="number").columns

plt.figure(figsize=(12, 6))
df_iron[feature_cols].boxplot()
plt.title("Boxplots der numerischen Features – Iron Deficiency Anemia")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas_profiling
from pydantic_settings import BaseSettings # NEW

df2 = pd.read_csv("diagnosed_cbc_data_v4.csv", sep=",")
profile = df2.profile_report(html={'style':{'full_width':True}})
# Save report uncomment line below, if you want to save the report
#profile.to_file(output_file="sgv-profile.html")
profile
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Temp\ipykernel_15660\1164236194.py in ?()
#       1 from pydantic_settings import BaseSettings # NEW
#       2
#       3 df2 = pd.read_csv("diagnosed_cbc_data_v4.csv", sep=",")
# ----> 4 profile = df2.profile_report(html={'style':{'full_width':True}})
#       5 # Save report uncomment line below, if you want to save the report
#       6 #profile.to_file(output_file="sgv-profile.html")
#       7 profile
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# ...
